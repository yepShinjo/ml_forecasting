# %% [markdown]
# # the_dogs_paw

# %%
# !pip install pandas
# !pip install pystan==2.19.1.1
# !pip install prophet
# !pip install boto3

import pandas as pd
import numpy as np
from prophet import Prophet
import boto3
import os
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting pystan==2.19.1.1
#   Using cached pystan-2.19.1.1.tar.gz (16.2 MB)
#   Preparing metadata (setup.py) ... done
# Collecting Cython!=0.25.1,>=0.22 (from pystan==2.19.1.1)
#   Using cached cython-3.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.7 in /opt/conda/lib/python3.12/site-packages (from pystan==2.19.1.1) (1.26.4)
# Using cached cython-3.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Building wheels for collected packages: pystan
#   Building wheel for pystan (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [3 lines of output]
#       /tmp/pip-install-428dkp3e/pystan_3e6fa25fa947409fb6b9a0e0795e89a6/setup.py:61: DeprecationWarning: Attribute s is deprecated and will be removed in Python 3.14; use value instead
#         self.version = node.value.s
#       Cython>=0.22 and NumPy are required.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pystan
#   Running setup.py clean for pystan
# Failed to build pystan
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (pystan)
# Requirement already satisfied: prophet in /opt/conda/lib/python3.12/site-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.12/site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from prophet) (3.10.1)
# Requirement already satisfied: pandas>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from prophet) (2.2.3)
# Requirement already satisfied: holidays<1,>=0.25 in /opt/conda/lib/python3.12/site-packages (from prophet) (0.73)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/conda/lib/python3.12/site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.12/site-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.12/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.12/site-packages (1.37.1)
# Requirement already satisfied: botocore<1.38.0,>=1.37.1 in /opt/conda/lib/python3.12/site-packages (from boto3) (1.37.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from boto3) (0.11.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<1.38.0,>=1.37.1->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<1.38.0,>=1.37.1->boto3) (2.4.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.1->boto3) (1.17.0)

# %%
import sagemaker
print(sagemaker.get_execution_role())
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# arn:aws:iam::059670545459:role/service-role/AmazonSageMaker-ExecutionRole-20250521T113889

# %% [markdown]
# ## S3 Setup

# %%
bucket = 'thedogspaw-small-forecast-data'  # <--- change to your S3 bucket

# Connect to S3
s3 = boto3.client('s3')

def s3_get(key, local):
    s3.download_file(bucket, key, local)

# Download all required files to /tmp
s3_get('datasets/thedogspaw_phppos_items.csv',         '/tmp/items.csv')
s3_get('datasets/thedogspaw_phppos_locations.csv',     '/tmp/locations.csv')
s3_get('datasets/thedogspaw_phppos_location_items.csv','/tmp/location_items.csv')
s3_get('datasets/thedogspaw_phppos_sales.csv',         '/tmp/sales.csv')
s3_get('datasets/thedogspaw_phppos_sales_items.csv',   '/tmp/sales_items.csv')

# %%
items_df         = pd.read_csv('/tmp/items.csv')
locations_df     = pd.read_csv('/tmp/locations.csv')
locations_item_df= pd.read_csv('/tmp/location_items.csv')
sales_df         = pd.read_csv('/tmp/sales.csv', parse_dates=['sale_time'])
sales_items_df   = pd.read_csv('/tmp/sales_items.csv')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)   # set to None to show all rows if needed

display(items_df.head())
# Out:
# /tmp/ipykernel_17858/3107525308.py:1: DtypeWarning: Columns (56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   items_df         = pd.read_csv('/tmp/items.csv')
# /tmp/ipykernel_17858/3107525308.py:4: DtypeWarning: Columns (5,29,37,38,40,41,53,54,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales_df         = pd.read_csv('/tmp/sales.csv', parse_dates=['sale_time'])
# /tmp/ipykernel_17858/3107525308.py:5: DtypeWarning: Columns (6,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales_items_df   = pd.read_csv('/tmp/sales_items.csv')
#                                                 name  category_id  \
# 0  Earthborn Holistic Grain Free - Meadow Feast -...          7.0
# 1                                   Puppy Groom - 25         13.0
# 2                                   Puppy Groom - 30         13.0
# 3                                   Puppy Groom - 35         13.0
# 4                                   Bubble Bath - 35         13.0
#
#    supplier_id  manufacturer_id item_number product_id  ecommerce_product_id  \
# 0          4.0              NaN         NaN        NaN                   NaN
# 1         15.0              NaN         NaN        NaN                   NaN
# 2         15.0              NaN         NaN        NaN                   NaN
# 3         15.0              NaN         NaN        NaN                   NaN
# 4         15.0              NaN         NaN        NaN                   NaN
#
#    ecommerce_product_quantity description size  tax_included  cost_price  \
# 0                         NaN         NaN  NaN             0       11.99
# 1                         NaN         NaN  NaN             0       12.50
# 2                         NaN         NaN  NaN             0       15.00
# 3                         NaN         NaN  NaN             0       17.50
# 4                         NaN         NaN  NaN             0       17.50
#
#    unit_price  promo_price start_date end_date  reorder_level  expire_days  \
# 0       16.99          NaN        NaN      NaN            1.0          NaN
# 1       25.00          NaN        NaN      NaN            1.0          NaN
# 2       30.00          NaN        NaN      NaN            1.0          NaN
# 3       35.00          NaN        NaN      NaN            1.0          NaN
# 4       35.00          NaN        NaN      NaN            1.0          NaN
#
#    item_id  allow_alt_description  is_serialized  override_default_tax  \
# 0        1                      0              0                     0
# 1        2                      1              0                     0
# 2        3                      1              0                     0
# 3        4                      1              0                     0
# 4        5                      1              0                     0
#
#    is_ecommerce  is_service  is_ebt_item  commission_percent  \
# 0             1           0            0                 0.0
# 1             1           1            0                 NaN
# 2             1           1            0                 NaN
# 3             1           1            0                 NaN
# 4             1           1            0                 NaN
#
#   commission_percent_type  commission_fixed  change_cost_price  \
# 0           selling_price               0.0                  0
# 1                     NaN               NaN                  0
# 2                     NaN               NaN                  0
# 3                     NaN               NaN                  0
# 4                     NaN               NaN                  0
#
#    disable_loyalty  deleted        last_modified  ecommerce_last_modified  \
# 0                0        1  2017-04-19 13:24:29                      NaN
# 1                0        1  2020-09-21 09:52:32                      NaN
# 2                0        1  2020-09-21 09:52:32                      NaN
# 3                0        1  2020-09-21 09:52:32                      NaN
# 4                0        1  2020-09-19 15:58:05                      NaN
#
#    tax_class_id  replenish_level  system_item  max_discount_percent  \
# 0           NaN              NaN            0                   NaN
# 1           NaN              NaN            0                   NaN
# 2           NaN              NaN            0                   NaN
# 3           NaN              NaN            0                   NaN
# 4           NaN              NaN            0                   NaN
#
#    max_edit_price  min_edit_price  custom_field_1_value  custom_field_2_value  \
# 0             NaN             NaN                   NaN                   NaN
# 1             NaN             NaN                   NaN                   NaN
# 2             NaN             NaN                   NaN                   NaN
# 3             NaN             NaN                   NaN                   NaN
# 4             NaN             NaN                   NaN                   NaN
#
#    custom_field_3_value  custom_field_4_value  custom_field_5_value  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    custom_field_6_value  custom_field_7_value  custom_field_8_value  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    custom_field_9_value  custom_field_10_value  required_age  verify_age  \
# 0                   NaN                    NaN           NaN           0
# 1                   NaN                    NaN           NaN           0
# 2                   NaN                    NaN           NaN           0
# 3                   NaN                    NaN           NaN           0
# 4                   NaN                    NaN           NaN           0
#
#    weight  length  width  height  ecommerce_shipping_class_id  \
# 0     NaN     NaN    NaN     NaN                          NaN
# 1     NaN     NaN    NaN     NaN                          NaN
# 2     NaN     NaN    NaN     NaN                          NaN
# 3     NaN     NaN    NaN     NaN                          NaN
# 4     NaN     NaN    NaN     NaN                          NaN
#
#   long_description  allow_price_override_regardless_of_permissions  \
# 0              NaN                                               0
# 1              NaN                                               0
# 2              NaN                                               0
# 3              NaN                                               0
# 4              NaN                                               0
#
#    main_image_id  only_integer  is_series_package  series_quantity  \
# 0            NaN             0                  0              NaN
# 1            NaN             0                  0              NaN
# 2            NaN             0                  0              NaN
# 3            NaN             0                  0              NaN
# 4            NaN             0                  0              NaN
#
#    series_days_to_use_within  is_barcoded  default_quantity  \
# 0                        NaN            1               NaN
# 1                        NaN            1               NaN
# 2                        NaN            1               NaN
# 3                        NaN            1               NaN
# 4                        NaN            1               NaN
#
#    disable_from_price_rules          last_edited  info_popup  item_inactive  \
# 0                         0  2017-04-19 13:24:29         NaN              0
# 1                         0  2017-04-19 13:24:29         NaN              0
# 2                         0  2018-09-28 15:41:48         NaN              0
# 3                         0  2017-04-19 13:24:29         NaN              0
# 4                         0  2019-07-09 15:28:39         NaN              0
#
#    barcode_name  tags  is_favorite  loyalty_multiplier  \
# 0           NaN   NaN            0                 NaN
# 1           NaN   NaN            0                 NaN
# 2           NaN   NaN            0                 NaN
# 3           NaN   NaN            0                 NaN
# 4           NaN   NaN            0                 NaN
#
#    ecommerce_inventory_item_id weight_unit  is_recurring  startup_cost  \
# 0                          NaN         NaN             0           0.0
# 1                          NaN         NaN             0           0.0
# 2                          NaN         NaN             0           0.0
# 3                          NaN         NaN             0           0.0
# 4                          NaN         NaN             0           0.0
#
#    prorated  interval  weekday  day_number  month  day  \
# 0         0       NaN      NaN         NaN    NaN  NaN
# 1         0       NaN      NaN         NaN    NaN  NaN
# 2         0       NaN      NaN         NaN    NaN  NaN
# 3         0       NaN      NaN         NaN    NaN  NaN
# 4         0       NaN      NaN         NaN    NaN  NaN
#
#    shopify_item_level_inventory_policy  non_profit_sale  \
# 0                                  NaN                0
# 1                                  NaN                0
# 2                                  NaN                0
# 3                                  NaN                0
# 4                                  NaN                0
#
#    ecommerce_first_variation_id  limited_sales_quantity
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN

# %% [markdown]
# ## Preprocess sales.csv, items.csv and sale_items.csv NaN columns to Str

# %%
sales_cols_as_str = [5, 29, 37, 38, 40, 41, 53, 54, 63]  # zero-based columns

sales_df = pd.read_csv(
    '/tmp/sales.csv',
    parse_dates=['sale_time'],
    dtype={col: str for col in sales_cols_as_str},
    low_memory=False
)
items_df = pd.read_csv(
    '/tmp/items.csv',
    dtype={56: str, 74: str},  # or use actual column names
    low_memory=False
)
sales_items_df = pd.read_csv(
    '/tmp/sales_items.csv',
    dtype={6: str, 23: str},   # or use names!
    low_memory=False
)

# %% [markdown]
# ## Sanity Check

# %%
# Check for duplicate item_ids
duplicates = items_df[items_df.duplicated('item_id', keep=False)]
print(f"Found {duplicates['item_id'].nunique()} duplicated item_ids.")
print(duplicates.sort_values('item_id'))

# Check for duplicate item names
name_dupes = items_df[items_df.duplicated('name', keep=False)]
print(f"Found {name_dupes['name'].nunique()} duplicated item names.")
print(name_dupes.sort_values('name'))

# See name duplicate counts
name_counts = items_df['name'].value_counts()
dupe_names = name_counts[name_counts > 1].index.tolist()
print(f"Found {len(dupe_names)} item names with duplicates.")
print(dupe_names[:20])

# See all items with duplicate names
dupes = items_df[items_df['name'].isin(dupe_names)].sort_values('name')
print(dupes[['item_id', 'name', 'category_id', 'supplier_id']].head(30))
# Out:
# Found 0 duplicated item_ids.
# Empty DataFrame
# Columns: [name, category_id, supplier_id, manufacturer_id, item_number, product_id, ecommerce_product_id, ecommerce_product_quantity, description, size, tax_included, cost_price, unit_price, promo_price, start_date, end_date, reorder_level, expire_days, item_id, allow_alt_description, is_serialized, override_default_tax, is_ecommerce, is_service, is_ebt_item, commission_percent, commission_percent_type, commission_fixed, change_cost_price, disable_loyalty, deleted, last_modified, ecommerce_last_modified, tax_class_id, replenish_level, system_item, max_discount_percent, max_edit_price, min_edit_price, custom_field_1_value, custom_field_2_value, custom_field_3_value, custom_field_4_value, custom_field_5_value, custom_field_6_value, custom_field_7_value, custom_field_8_value, custom_field_9_value, custom_field_10_value, required_age, verify_age, weight, length, width, height, ecommerce_shipping_class_id, long_description, allow_price_override_regardless_of_permissions, main_image_id, only_integer, is_series_package, series_quantity, series_days_to_use_within, is_barcoded, default_quantity, disable_from_price_rules, last_edited, info_popup, item_inactive, barcode_name, tags, is_favorite, loyalty_multiplier, ecommerce_inventory_item_id, weight_unit, is_recurring, startup_cost, prorated, interval, weekday, day_number, month, day, shopify_item_level_inventory_policy, non_profit_sale, ecommerce_first_variation_id, limited_sales_quantity]
# Index: []
# Found 183 duplicated item names.
#       name  category_id  supplier_id  manufacturer_id item_number product_id  \
# 662      0          2.0          NaN              NaN         NaN        NaN
# 1391     0          2.0          NaN              NaN         NaN        NaN
# 1310     0          2.0          NaN              NaN         NaN        NaN
# 620      0          2.0          NaN              NaN         NaN        NaN
# 2322     0          2.0          NaN              NaN         NaN        NaN
# ...    ...          ...          ...              ...         ...        ...
# 11684  NaN          NaN          NaN              NaN         NaN        NaN
# 11685  NaN          NaN          NaN              NaN         NaN        NaN
# 11699  NaN          NaN          NaN              NaN         NaN        NaN
# 11700  NaN          NaN          NaN              NaN         NaN        NaN
# 11701  NaN          NaN          NaN              NaN         NaN        NaN
#
#        ecommerce_product_id  ecommerce_product_quantity description size  \
# 662                     NaN                         NaN           0  NaN
# 1391                    NaN                         NaN           0    0
# 1310                    NaN                         NaN           0    0
# 620                     NaN                         NaN           0  NaN
# 2322                    NaN                         NaN           0    0
# ...                     ...                         ...         ...  ...
# 11684                   NaN                         NaN         NaN  NaN
# 11685                   NaN                         NaN         NaN  NaN
# 11699                   NaN                         NaN         NaN  NaN
# 11700                   NaN                         NaN         NaN  NaN
# 11701                   NaN                         NaN         NaN  NaN
#
#        tax_included  cost_price  unit_price  promo_price start_date end_date  \
# 662               0         0.0        0.00          NaN        NaN      NaN
# 1391              0         0.0        0.00          NaN        NaN      NaN
# 1310              0         0.0        0.00          NaN        NaN      NaN
# 620               0         0.0        0.00          NaN        NaN      NaN
# 2322              0         0.0        0.00          NaN        NaN      NaN
# ...             ...         ...         ...          ...        ...      ...
# 11684             0         0.0        0.00          NaN        NaN      NaN
# 11685             0         0.0        0.00          NaN        NaN      NaN
# 11699             0         3.0        6.99          NaN        NaN      NaN
# 11700             0         0.0        0.00          NaN        NaN      NaN
# 11701             0         0.0        0.00          NaN        NaN      NaN
#
#        reorder_level  expire_days  item_id  allow_alt_description  \
# 662              0.0          NaN      663                      0
# 1391             NaN          NaN     1393                      0
# 1310             NaN          NaN     1312                      0
# 620              0.0          NaN      621                      0
# 2322             NaN          NaN     2326                      0
# ...              ...          ...      ...                    ...
# 11684            NaN          NaN    11735                      0
# 11685            NaN          NaN    11736                      0
# 11699            NaN          NaN    11751                      0
# 11700            NaN          NaN    11752                      0
# 11701            NaN          NaN    11753                      0
#
#        is_serialized  override_default_tax  is_ecommerce  is_service  \
# 662                0                     0             1           0
# 1391               0                     0             1           0
# 1310               0                     0             1           0
# 620                0                     0             1           0
# 2322               0                     0             1           0
# ...              ...                   ...           ...         ...
# 11684              0                     0             1           0
# 11685              0                     0             1           0
# 11699              0                     0             1           0
# 11700              0                     0             1           0
# 11701              0                     0             1           0
#
#        is_ebt_item  commission_percent commission_percent_type  \
# 662              0                 0.0           selling_price
# 1391             0                 NaN                     NaN
# 1310             0                 NaN                     NaN
# 620              0                 0.0           selling_price
# 2322             0                 NaN                     NaN
# ...            ...                 ...                     ...
# 11684            0                 0.0                     NaN
# 11685            0                 0.0                     NaN
# 11699            0                 NaN                     NaN
# 11700            0                 0.0                     NaN
# 11701            0                 0.0                     NaN
#
#        commission_fixed  change_cost_price  disable_loyalty  deleted  \
# 662                 0.0                  0                0        1
# 1391                NaN                  0                0        1
# 1310                NaN                  0                0        1
# 620                 0.0                  0                0        1
# 2322                NaN                  0                0        1
# ...                 ...                ...              ...      ...
# 11684               0.0                  0                0        0
# 11685               0.0                  0                0        0
# 11699               NaN                  0                0        0
# 11700               0.0                  0                0        0
# 11701               0.0                  0                0        0
#
#              last_modified  ecommerce_last_modified  tax_class_id  \
# 662    2017-04-19 13:24:29                      NaN           NaN
# 1391   2017-04-19 13:24:29                      NaN           NaN
# 1310   2017-04-19 13:24:29                      NaN           NaN
# 620    2017-04-19 13:24:29                      NaN           NaN
# 2322   2017-04-19 13:24:29                      NaN           NaN
# ...                    ...                      ...           ...
# 11684  2025-05-15 11:42:02                      NaN           NaN
# 11685  2025-05-15 11:42:02                      NaN           NaN
# 11699  2025-05-22 14:15:52                      NaN           NaN
# 11700  2025-05-22 14:15:53                      NaN           NaN
# 11701  2025-05-22 14:15:54                      NaN           NaN
#
#        replenish_level  system_item  max_discount_percent  max_edit_price  \
# 662                NaN            0                   NaN             NaN
# 1391               NaN            0                   NaN             NaN
# 1310               NaN            0                   NaN             NaN
# 620                NaN            0                   NaN             NaN
# 2322               NaN            0                   NaN             NaN
# ...                ...          ...                   ...             ...
# 11684              NaN            0                   NaN             NaN
# 11685              NaN            0                   NaN             NaN
# 11699              NaN            0                   NaN             NaN
# 11700              NaN            0                   NaN             NaN
# 11701              NaN            0                   NaN             NaN
#
#        min_edit_price  custom_field_1_value  custom_field_2_value  \
# 662               NaN                   NaN                   NaN
# 1391              NaN                   NaN                   NaN
# 1310              NaN                   NaN                   NaN
# 620               NaN                   NaN                   NaN
# 2322              NaN                   NaN                   NaN
# ...               ...                   ...                   ...
# 11684             NaN                   NaN                   NaN
# 11685             NaN                   NaN                   NaN
# 11699             NaN                   NaN                   NaN
# 11700             NaN                   NaN                   NaN
# 11701             NaN                   NaN                   NaN
#
#        custom_field_3_value  custom_field_4_value  custom_field_5_value  \
# 662                     NaN                   NaN                   NaN
# 1391                    NaN                   NaN                   NaN
# 1310                    NaN                   NaN                   NaN
# 620                     NaN                   NaN                   NaN
# 2322                    NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 11684                   NaN                   NaN                   NaN
# 11685                   NaN                   NaN                   NaN
# 11699                   NaN                   NaN                   NaN
# 11700                   NaN                   NaN                   NaN
# 11701                   NaN                   NaN                   NaN
#
#        custom_field_6_value  custom_field_7_value  custom_field_8_value  \
# 662                     NaN                   NaN                   NaN
# 1391                    NaN                   NaN                   NaN
# 1310                    NaN                   NaN                   NaN
# 620                     NaN                   NaN                   NaN
# 2322                    NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 11684                   NaN                   NaN                   NaN
# 11685                   NaN                   NaN                   NaN
# 11699                   NaN                   NaN                   NaN
# 11700                   NaN                   NaN                   NaN
# 11701                   NaN                   NaN                   NaN
#
#        custom_field_9_value  custom_field_10_value  required_age  verify_age  \
# 662                     NaN                    NaN           NaN           0
# 1391                    NaN                    NaN           NaN           0
# 1310                    NaN                    NaN           NaN           0
# 620                     NaN                    NaN           NaN           0
# 2322                    NaN                    NaN           NaN           0
# ...                     ...                    ...           ...         ...
# 11684                   NaN                    NaN           NaN           0
# 11685                   NaN                    NaN           NaN           0
# 11699                   NaN                    NaN           NaN           0
# 11700                   NaN                    NaN           NaN           0
# 11701                   NaN                    NaN           NaN           0
#
#        weight  length  width  height  ecommerce_shipping_class_id  \
# 662       NaN     NaN    NaN     NaN                          NaN
# 1391      NaN     NaN    NaN     NaN                          NaN
# 1310      NaN     NaN    NaN     NaN                          NaN
# 620       NaN     NaN    NaN     NaN                          NaN
# 2322      NaN     NaN    NaN     NaN                          NaN
# ...       ...     ...    ...     ...                          ...
# 11684     NaN     NaN    NaN     NaN                          NaN
# 11685     NaN     NaN    NaN     NaN                          NaN
# 11699     NaN     NaN    NaN     NaN                          NaN
# 11700     NaN     NaN    NaN     NaN                          NaN
# 11701     NaN     NaN    NaN     NaN                          NaN
#
#       long_description  allow_price_override_regardless_of_permissions  \
# 662                  0                                               0
# 1391                 0                                               0
# 1310                 0                                               0
# 620                  0                                               0
# 2322                 0                                               0
# ...                ...                                             ...
# 11684              NaN                                               0
# 11685              NaN                                               0
# 11699              NaN                                               0
# 11700              NaN                                               0
# 11701              NaN                                               0
#
#        main_image_id  only_integer  is_series_package  series_quantity  \
# 662              NaN             0                  0              NaN
# 1391             NaN             0                  0              NaN
# 1310             NaN             0                  0              NaN
# 620              NaN             0                  0              NaN
# 2322             NaN             0                  0              NaN
# ...              ...           ...                ...              ...
# 11684            NaN             0                  0              NaN
# 11685            NaN             0                  0              NaN
# 11699            NaN             0                  0              NaN
# 11700            NaN             0                  0              NaN
# 11701            NaN             0                  0              NaN
#
#        series_days_to_use_within  is_barcoded  default_quantity  \
# 662                          NaN            1               NaN
# 1391                         NaN            1               NaN
# 1310                         NaN            1               NaN
# 620                          NaN            1               NaN
# 2322                         NaN            1               NaN
# ...                          ...          ...               ...
# 11684                        NaN            1               NaN
# 11685                        NaN            1               NaN
# 11699                        NaN            1               NaN
# 11700                        NaN            1               NaN
# 11701                        NaN            1               NaN
#
#        disable_from_price_rules          last_edited  info_popup  \
# 662                           0  2017-04-19 13:24:29         NaN
# 1391                          0  2017-04-19 13:24:29         NaN
# 1310                          0  2017-04-19 13:24:29         NaN
# 620                           0  2017-04-19 13:24:29         NaN
# 2322                          0  2017-04-19 13:24:29         NaN
# ...                         ...                  ...         ...
# 11684                         0                  NaN         NaN
# 11685                         0                  NaN         NaN
# 11699                         0                  NaN         NaN
# 11700                         0                  NaN         NaN
# 11701                         0                  NaN         NaN
#
#        item_inactive  barcode_name  tags  is_favorite  loyalty_multiplier  \
# 662                0           NaN   NaN            0                 NaN
# 1391               0           NaN   NaN            0                 NaN
# 1310               0           NaN   NaN            0                 NaN
# 620                0           NaN   NaN            0                 NaN
# 2322               0           NaN   NaN            0                 NaN
# ...              ...           ...   ...          ...                 ...
# 11684              0           NaN   NaN            0                 NaN
# 11685              0           NaN   NaN            0                 NaN
# 11699              0           NaN   NaN            0                 NaN
# 11700              0           NaN   NaN            0                 NaN
# 11701              0           NaN   NaN            0                 NaN
#
#        ecommerce_inventory_item_id weight_unit  is_recurring  startup_cost  \
# 662                            NaN         NaN             0           0.0
# 1391                           NaN         NaN             0           0.0
# 1310                           NaN         NaN             0           0.0
# 620                            NaN         NaN             0           0.0
# 2322                           NaN         NaN             0           0.0
# ...                            ...         ...           ...           ...
# 11684                          NaN         NaN             0           0.0
# 11685                          NaN         NaN             0           0.0
# 11699                          NaN         NaN             0           0.0
# 11700                          NaN         NaN             0           0.0
# 11701                          NaN         NaN             0           0.0
#
#        prorated  interval  weekday  day_number  month  day  \
# 662           0       NaN      NaN         NaN    NaN  NaN
# 1391          0       NaN      NaN         NaN    NaN  NaN
# 1310          0       NaN      NaN         NaN    NaN  NaN
# 620           0       NaN      NaN         NaN    NaN  NaN
# 2322          0       NaN      NaN         NaN    NaN  NaN
# ...         ...       ...      ...         ...    ...  ...
# 11684         0       NaN      NaN         NaN    NaN  NaN
# 11685         0       NaN      NaN         NaN    NaN  NaN
# 11699         0       NaN      0.0         1.0    1.0  1.0
# 11700         0       NaN      NaN         NaN    NaN  NaN
# 11701         0       NaN      NaN         NaN    NaN  NaN
#
#        shopify_item_level_inventory_policy  non_profit_sale  \
# 662                                    NaN                0
# 1391                                   NaN                0
# 1310                                   NaN                0
# 620                                    NaN                0
# 2322                                   NaN                0
# ...                                    ...              ...
# 11684                                  NaN                0
# 11685                                  NaN                0
# 11699                                  NaN                0
# 11700                                  NaN                0
# 11701                                  NaN                0
#
#        ecommerce_first_variation_id  limited_sales_quantity
# 662                             NaN                     NaN
# 1391                            NaN                     NaN
# 1310                            NaN                     NaN
# 620                             NaN                     NaN
# 2322                            NaN                     NaN
# ...                             ...                     ...
# 11684                           NaN                     NaN
# 11685                           NaN                     NaN
# 11699                           NaN                     NaN
# 11700                           NaN                     NaN
# 11701                           NaN                     NaN
#
# [564 rows x 87 columns]
# Found 183 item names with duplicates.
# ['Doggie Design Harness- BROWN', 'Hip Doggie Pink Winston', '0', 'Doggie Design Harness- Baby BLUE', 'Gooby Fleece Vest Turquoise', 'Acana Heritage Meat 4.5#', 'Bakery', 'Hip Doggie Bone Charm', 'Gooby Fleece Vest PINK', 'Weruva harmony ven salm', 'PD Orbee-Tuff Blue Bone', 'PD Orbee-Tuff Green Bone', 'PD Orbee-Tuff Pink Bone', 'Rhinestone baby double collar ', 'Weruva Goldie Lox', 'Doggie Design Harness- PURPLE', 'A Pup Above: Beef  (Clone)', 'Snooks SP Chips', 'PD Orbee DoubleTuff Orange', 'N-Bone Quad Pmpkn']
#        item_id                                          name  category_id  \
# 662        663                                             0          2.0
# 1391      1393                                             0          2.0
# 1310      1312                                             0          2.0
# 620        621                                             0          2.0
# 2322      2326                                             0          2.0
# 618        619                                             0          2.0
# 8211      8242                    A Pup Above: Beef  (Clone)         37.0
# 8210      8241                    A Pup Above: Beef  (Clone)         37.0
# 8212      8243                    A Pup Above: Beef  (Clone)         37.0
# 3888      3912                      Acana Heritage Meat 4.5#          8.0
# 3042      3057                      Acana Heritage Meat 4.5#          8.0
# 3043      3058                      Acana Heritage Meat 4.5#          8.0
# 3045      3060                      Acana Heritage Meat 4.5#          8.0
# 712        713                        Acana Wild Prairie 30#          8.0
# 471        472                        Acana Wild Prairie 30#          8.0
# 10216    10250                 BP Deshedding Shampoo (Clone)         22.0
# 10215    10249                 BP Deshedding Shampoo (Clone)         22.0
# 10279    10313                                        Bakery          3.0
# 10276    10310                                        Bakery          3.0
# 8216      8247                                        Bakery          3.0
# 10275    10309                                        Bakery          3.0
# 7508      7537                                Bakery - $0.99          3.0
# 2761      2774                                Bakery - $0.99         25.0
# 10102    10136  Better Biscuit Chicken Crunchy Dog Treat 2lb         59.0
# 9498      9530  Better Biscuit Chicken Crunchy Dog Treat 2lb         25.0
# 4620      4646                         Bocce's Bees & Cheese         25.0
# 4171      4195                         Bocce's Bees & Cheese         25.0
# 4170      4194                           Bocce's Duck Confit         25.0
# 4133      4157                           Bocce's Duck Confit         25.0
# 4234      4258                            Bocce's Farm Chick         25.0
#
#        supplier_id
# 662            NaN
# 1391           NaN
# 1310           NaN
# 620            NaN
# 2322           NaN
# 618            NaN
# 8211           NaN
# 8210           NaN
# 8212           NaN
# 3888          46.0
# 3042           NaN
# 3043          46.0
# 3045          46.0
# 712           46.0
# 471            3.0
# 10216         48.0
# 10215         48.0
# 10279          NaN
# 10276          NaN
# 8216          15.0
# 10275          NaN
# 7508           NaN
# 2761           NaN
# 10102          NaN
# 9498           NaN
# 4620           4.0
# 4171           4.0
# 4170           4.0
# 4133           4.0
# 4234           4.0

# %% [markdown]
# ## Merge Sales Items with Sales (Add date/store info to item sales)

# %%
item_sales = sales_items_df.merge(
    sales_df[['sale_id', 'sale_time', 'location_id']],
    on='sale_id', how='left'
)
item_sales['date'] = pd.to_datetime(item_sales['sale_time']).dt.date
print(item_sales[['sale_id', 'item_id', 'location_id', 'date', 'quantity_purchased']].tail(10))
# Out:
#         sale_id  item_id  location_id        date  quantity_purchased
# 525719   204502     8185            1  2025-05-23                 1.0
# 525720   204502     8244            1  2025-05-23                 1.0
# 525721   204502     8651            1  2025-05-23                 1.0
# 525722   204502     9578            1  2025-05-23                 3.0
# 525723   204502    10874            1  2025-05-23                 4.0
# 525724   204502    11110            1  2025-05-23                 1.0
# 525725   204503    11543            1  2025-05-23                 1.0
# 525726   204504     8244            1  2025-05-23                 1.0
# 525727   204504     8247            1  2025-05-23                 2.0
# 525728   204504     8247            1  2025-05-23                 4.0

# %% [markdown]
# ## Aggregate Daily Sales Per Item Per Store

# %%
recent_daily_item_sales = (
    item_sales.groupby(['location_id', 'item_id', 'date'])['quantity_purchased']
    .sum()
    .reset_index()
    .sort_values(['location_id', 'item_id', 'date'])
)
print(daily_item_sales.tail(10))
# Out:
#         location_id  item_id        date  quantity_purchased
# 344887            2    11522  2025-04-09                 1.0
# 344888            2    11595  2025-04-06                 1.0
# 344889            2    11595  2025-04-13                 1.0
# 344890            2    11595  2025-05-15                 1.0
# 344891            2    11600  2025-03-30                 1.0
# 344892            2    11622  2025-04-13                -1.0
# 344893            2    11658  2025-04-29                 1.0
# 344894            2    11658  2025-05-09                 1.0
# 344895            2    11660  2025-04-24                 1.0
# 344896            2    11727  2025-05-20                 1.0

# %% [markdown]
# ## Calculate enough history (have a minimum 20 total sales day after filtering) for forecasting

# %%
item_day_counts = (
    recent_daily_item_sales.groupby(['location_id', 'item_id'])['date']
    .nunique()
    .reset_index()
    .rename(columns={'date': 'num_days_with_sales'})
)
item_day_counts['enough_history'] = item_day_counts['num_days_with_sales'] >= 20
print(item_day_counts.head(10))
print(f"Forecastable items: {item_day_counts['enough_history'].sum()} / {len(item_day_counts)}")
# Out:
#    location_id  item_id  num_days_with_sales  enough_history
# 0            1        1                    1           False
# 1            1        2                   13           False
# 2            1        3                   10           False
# 3            1        4                   45            True
# 4            1        5                  966            True
# 5            1        6                  841            True
# 6            1        7                  640            True
# 7            1        8                  622            True
# 8            1        9                  207            True
# 9            1       10                  413            True
# Forecastable items: 2510 / 11467

# %% [markdown]
# ## The main shit. Forecast / fallback per item per store

# %%
from tqdm.notebook import tqdm

lead_time_days = 7
z = 1.65
results = []

for _, row in tqdm(item_day_counts.iterrows(), total=len(item_day_counts)):
    loc = row['location_id']
    item = row['item_id']
    enough = row['enough_history']

    item_sales_history = daily_item_sales[
        (daily_item_sales['location_id'] == loc) &
        (daily_item_sales['item_id'] == item)
    ].copy()
    item_sales_history = item_sales_history.rename(columns={'date': 'ds', 'quantity_purchased': 'y'})
    item_sales_history['ds'] = pd.to_datetime(item_sales_history['ds'])

    # Apply 12-month cutoff in the loop, to match recent_daily_item_sales
    cutoff_in_loop = item_sales_history['ds'].max() - pd.DateOffset(months=12)
    item_sales_history = item_sales_history[item_sales_history['ds'] >= cutoff_in_loop]

    reorder_level = None
    replenish_level = None

    if enough and len(item_sales_history) >= 20:
        try:
            m = Prophet(daily_seasonality=True)
            m.fit(item_sales_history)
            future = m.make_future_dataframe(periods=lead_time_days)
            forecast = m.predict(future)
            lead_forecast = forecast.tail(lead_time_days)
            demand_lt = lead_forecast['yhat'].sum()
            sigma_lt = (lead_forecast['yhat_upper'].sum() - lead_forecast['yhat_lower'].sum()) / 3.29
            safety_stock = z * sigma_lt
            reorder_level = int(np.round(demand_lt + safety_stock))
            replenish_level = int(np.round(reorder_level + demand_lt))
        except Exception as e:
            last_week = item_sales_history.sort_values('ds').tail(7)
            avg_daily = last_week['y'].mean() if len(last_week) else 1
            demand_lt = avg_daily * lead_time_days
            reorder_level = int(np.round(demand_lt))
            replenish_level = int(np.round(demand_lt * 2))
    else:
        last_week = item_sales_history.sort_values('ds').tail(7)
        avg_daily = last_week['y'].mean() if len(last_week) else 1
        demand_lt = avg_daily * lead_time_days
        reorder_level = int(np.round(demand_lt))
        replenish_level = int(np.round(demand_lt * 2))

    results.append({
        'location_id': loc,
        'item_id': item,
        'reorder_level': reorder_level,
        'replenish_level': replenish_level,
        'enough_history': enough
    })

results_df = pd.DataFrame(results)
print(results_df.head(10))
print("-----------------")
print(results_df.tail(10))
# Out:
#   0%|          | 0/11467 [00:00<?, ?it/s]
# 08:03:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:40 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:40 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:40 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:40 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:49 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:49 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:49 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:49 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:00 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:01 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:01 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:01 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:01 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:01 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:02 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:02 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:07 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:07 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:07 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:07 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:09 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:10 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:34 - cmdstanpy - INFO - Chain [1] done processing
# ...
# 08:05:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:35 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:36 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:37 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:40 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:40 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:40 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:49 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:49 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:58 - cmdstanpy - INFO - Chain [1] done processing
#    location_id  item_id  reorder_level  replenish_level  enough_history
# 0            1        1             28               56           False
# 1            1        2              7               14           False
# 2            1        3              7               14           False
# 3            1        4              7               14            True
# 4            1        5             17               28            True
# 5            1        6             17               28            True
# 6            1        7             17               28            True
# 7            1        8             20               32            True
# 8            1        9             12               19            True
# 9            1       10             15               24            True
# -----------------
#        location_id  item_id  reorder_level  replenish_level  enough_history
# 11457            2    11501              7               14           False
# 11458            2    11502              7               14           False
# 11459            2    11503              7               14           False
# 11460            2    11522              7               14           False
# 11461            2    11595              7               14           False
# 11462            2    11600              7               14           False
# 11463            2    11622             -7              -14           False
# 11464            2    11658              7               14           False
# 11465            2    11660              7               14           False
# 11466            2    11727              7               14           False

# %%
# Merge item names
merged_results = results_df.merge(items_df[['item_id', 'name']], on='item_id', how='left')

# Last sale date for each (location, item)
last_sale_dates = (
    recent_daily_item_sales.groupby(['location_id', 'item_id'])['date']
    .max()
    .reset_index()
    .rename(columns={'date': 'last_sale_date'})
)

merged_results = merged_results.merge(last_sale_dates, on=['location_id', 'item_id'], how='left')

print(merged_results[['location_id', 'item_id', 'name', 'reorder_level', 'replenish_level', 'last_sale_date']].head(20))
# Out:
#     location_id  item_id                                               name  \
# 0             1        1  Earthborn Holistic Grain Free - Meadow Feast -...
# 1             1        2                                   Puppy Groom - 25
# 2             1        3                                   Puppy Groom - 30
# 3             1        4                                   Puppy Groom - 35
# 4             1        5                                   Bubble Bath - 35
# 5             1        6                                   Bubble Bath - 40
# 6             1        7                                   Bubble Bath - 45
# 7             1        8                                   Bubble Bath - 50
# 8             1        9                                   Bubble Bath - 55
# 9             1       10                                   Bubble Bath - 60
# 10            1       11                                   Bubble Bath - 65
# 11            1       12                                   Bubble Bath - 70
# 12            1       13                                    Nail Trim Basic
# 13            1       14                            Walk-in Nail Trim (Dog)
# 14            1       15                             Nail Painting (Add-on)
# 15            1       16                               Demat Svc Per 1/2 Hr
# 16            1       17                            Hand Strip Groom Per Hr
# 17            1       18                            Teeth Brushing (Add-on)
# 18            1       19                        Walk-in Face OR Fanny Trim
# 19            1       20                          Private Trim & Expression
#
#     reorder_level  replenish_level last_sale_date
# 0              28               56     2012-07-13
# 1               7               14     2017-10-18
# 2               7               14     2020-09-05
# 3               7               14     2020-09-05
# 4              17               28     2020-09-19
# 5              17               28     2020-09-19
# 6              17               28     2020-09-19
# 7              20               32     2020-09-17
# 8              12               19     2020-09-19
# 9              15               24     2020-09-19
# 10              9               16     2020-09-15
# 11             11               19     2020-09-16
# 12              8               16     2019-03-02
# 13             29               46     2025-05-23
# 14              7               14     2025-05-12
# 15              7               14     2020-06-13
# 16              7               14     2020-09-14
# 17             44               71     2025-05-23
# 18              9               18     2025-05-18
# 19              7               14     2021-08-18

# %%
results_key = 'results/thedogspaw_reorder_replenish_results.csv'
merged_results.to_csv('/tmp/thedogspaw_reorder_replenish_results.csv', index=False)
s3.upload_file('/tmp/thedogspaw_reorder_replenish_results.csv', bucket, results_key)
os.remove('/tmp/thedogspaw_reorder_replenish_results.csv')
print(f"✅ Reorder & replenish results written to s3://{bucket}/{results_key}")
# Out:
# ✅ Reorder & replenish results written to s3://thedogspaw-small-forecast-data/results/thedogspaw_reorder_replenish_results.csv
